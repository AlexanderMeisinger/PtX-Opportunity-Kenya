# %%
import pypsa
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Read base network

# %%
n_KE=pypsa.Network("/home/alex-charly/SSD/Kenya/pypsa-earth/results/Kenya/postnetworks/elec_s_2_ec_lcopt_Co2L0.00-3H_3H_2050_0.071_NZ_50export.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['H2 pipeline KE.10_1_AC -> KE.25_1_DC'], dtype='object', name='name')
# INFO:pypsa.io:Imported network elec_s_2_ec_lcopt_Co2L0.00-3H_3H_2050_0.071_NZ_50export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_KE_geo=pypsa.Network("/home/alex-charly/SSD/Kenya/pypsa-earth/results/Kenya_geo/postnetworks/elec_s_2_ec_lcopt_Co2L0.00-3H_3H_2050_0.071_NZ_50export.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['H2 pipeline KE.10_1_AC -> KE.25_1_DC'], dtype='object', name='name')
# INFO:pypsa.io:Imported network elec_s_2_ec_lcopt_Co2L0.00-3H_3H_2050_0.071_NZ_50export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_KE_geo_pot=pypsa.Network("/home/alex-charly/SSD/Kenya/pypsa-earth/results/Kenya_geo_pot/postnetworks/elec_s_2_ec_lcopt_Co2L0.00-144H_144H_2050_0.071_NZ_50export.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['H2 pipeline KE.10_1_AC -> KE.25_1_DC'], dtype='object', name='name')
# INFO:pypsa.io:Imported network elec_s_2_ec_lcopt_Co2L0.00-144H_144H_2050_0.071_NZ_50export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_KE_geo_pot_50res_0co2=pypsa.Network("/home/alex-charly/SSD/Kenya/pypsa-earth/results/Kenya_geo_pot/postnetworks/elec_s_2_ec_lcopt_Co2L0.00-144H-RES0.5_144H_2050_0.071_NZ_50export.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['H2 pipeline KE.10_1_AC -> KE.25_1_DC'], dtype='object', name='name')
# INFO:pypsa.io:Imported network elec_s_2_ec_lcopt_Co2L0.00-144H-RES0.5_144H_2050_0.071_NZ_50export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_KE_geo_pot_50res_50co2=pypsa.Network("/home/alex-charly/SSD/Kenya/pypsa-earth/results/Kenya_geo_pot/postnetworks/elec_s_2_ec_lcopt_Co2L0.50-144H-RES0.5_144H_2050_0.071_NZ_50export.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['H2 pipeline KE.10_1_AC -> KE.25_1_DC'], dtype='object', name='name')
# INFO:pypsa.io:Imported network elec_s_2_ec_lcopt_Co2L0.50-144H-RES0.5_144H_2050_0.071_NZ_50export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_KE_geo_pot100res_100co2=pypsa.Network("/home/alex-charly/SSD/Kenya/pypsa-earth/results/Kenya_geo_pot/postnetworks/elec_s_2_ec_lcopt_Co2L1.00-144H-RES1.0_144H_2050_0.071_NZ_50export.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['H2 pipeline KE.10_1_AC -> KE.25_1_DC'], dtype='object', name='name')
# INFO:pypsa.io:Imported network elec_s_2_ec_lcopt_Co2L1.00-144H-RES1.0_144H_2050_0.071_NZ_50export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_KE_geo_pot_80res_100co2=pypsa.Network("/home/alex-charly/SSD/Kenya/pypsa-earth/results/Kenya_geo_pot/postnetworks/elec_s_2_ec_lcopt_Co2L1.00-144H-RES0.75_144H_2050_0.071_NZ_50export.nc")
# Out:
# WARNING:pypsa.io:The following Link have buses which are not defined:
# Index(['H2 pipeline KE.10_1_AC -> KE.25_1_DC'], dtype='object', name='name')
# INFO:pypsa.io:Imported network elec_s_2_ec_lcopt_Co2L1.00-144H-RES0.75_144H_2050_0.071_NZ_50export.nc has buses, carriers, generators, global_constraints, lines, links, loads, storage_units, stores

# %%
n_KE_geo_pot_80res_100co2.statistics.energy_balance(comps=["Generator"])
# Out:
# component  carrier             bus_carrier
# Generator  Combined-Cycle Gas  Ac                                         4.925100e-01
#            Geothermal          Ac                                         2.253740e+06
#            Offshore Wind (AC)  Ac                                         2.427400e-01
#            Onshore Wind        Ac                                         6.278024e+05
#            Run of River        Ac                                         1.000469e+06
#            Solar               Ac                                         6.571199e+07
#            gas                 gas                                        2.908190e+00
#            load                Ac                                         9.100000e-04
#                                Battery Storage                            9.000000e-04
#                                Dc                                         3.000000e-05
# ...

# %%
n_KE.statistics()
# Out:
#                                                    Optimal Capacity  \
# Generator Combined-Cycle Gas                           6.391000e+02
#           Geothermal                                   3.840000e+02
#           Offshore Wind (AC)                           2.060000e-03
#           Onshore Wind                                 4.358175e+02
#           Run of River                                 3.562597e+02
# ...                                                             ...
# Store     residential urban decentral water tanks      2.150000e-03
#           services rural water tanks                   2.160000e-03
#           services urban decentral water tanks         2.170000e-03
#           solid biomass                                2.043000e+08
#           urban central water tanks                    2.551400e-01
#
#                                                    Installed Capacity  \
# Generator Combined-Cycle Gas                             6.391000e+02
# ...

# %%
n_KE_geo.statistics()
# Out:
#                                                    Optimal Capacity  \
# Generator Combined-Cycle Gas                           6.391000e+02
#           Geothermal                                   1.409918e+04
#           Offshore Wind (AC)                           1.500000e-04
#           Onshore Wind                                 4.358154e+02
#           Run of River                                 3.562597e+02
# ...                                                             ...
# Store     residential urban decentral water tanks      2.000000e-04
#           services rural water tanks                   1.900000e-04
#           services urban decentral water tanks         1.900000e-04
#           solid biomass                                2.043000e+08
#           urban central water tanks                    3.788000e-02
#
#                                                    Installed Capacity  \
# Generator Combined-Cycle Gas                             6.391000e+02
# ...

# %%
n_KE_geo_pot.statistics()
# Out:
#                                                    Optimal Capacity  \
# Generator Combined-Cycle Gas                           6.391000e+02
#           Geothermal                                   1.000000e+04
#           Offshore Wind (AC)                           7.100000e-04
#           Onshore Wind                                 4.358163e+02
#           Run of River                                 3.562597e+02
# ...                                                             ...
# Store     residential urban decentral water tanks      8.300000e-04
#           services rural water tanks                   8.000000e-04
#           services urban decentral water tanks         8.300000e-04
#           solid biomass                                2.043000e+08
#           urban central water tanks                    8.650000e-02
#
#                                                    Installed Capacity  \
# Generator Combined-Cycle Gas                             6.391000e+02
# ...

# %%
n_KE_geo_pot_50res_0co2.statistics()
# Out:
#                                                    Optimal Capacity  \
# Generator Combined-Cycle Gas                           6.391000e+02
#           Geothermal                                   3.840012e+02
#           Offshore Wind (AC)                           1.100000e-03
#           Onshore Wind                                 1.718422e+04
#           Run of River                                 3.562597e+02
# ...                                                             ...
# Store     residential urban decentral water tanks      7.500000e-04
#           services rural water tanks                   7.600000e-04
#           services urban decentral water tanks         7.400000e-04
#           solid biomass                                2.043000e+08
#           urban central water tanks                    7.613000e-02
#
#                                                    Installed Capacity  \
# Generator Combined-Cycle Gas                             6.391000e+02
# ...

# %%
n_KE_geo_pot_50res_50co2.statistics()
# Out:
#                                                    Optimal Capacity  \
# Generator Combined-Cycle Gas                           6.391000e+02
#           Geothermal                                   3.840014e+02
#           Offshore Wind (AC)                           1.470000e-03
#           Onshore Wind                                 1.718422e+04
#           Run of River                                 3.562597e+02
# ...                                                             ...
# Store     residential urban decentral water tanks      9.100000e-04
#           services rural water tanks                   9.400000e-04
#           services urban decentral water tanks         8.900000e-04
#           solid biomass                                2.043000e+08
#           urban central water tanks                    9.032000e-02
#
#                                                    Installed Capacity  \
# Generator Combined-Cycle Gas                             6.391000e+02
# ...

# %%
n_KE_geo_pot100res_100co2.statistics()
# Out:
#                                                    Optimal Capacity  \
# Generator Combined-Cycle Gas                           6.391000e+02
#           Geothermal                                   3.840015e+02
#           Offshore Wind (AC)                           1.440000e-03
#           Onshore Wind                                 1.529400e+05
#           Run of River                                 3.562597e+02
# ...                                                             ...
# Store     residential urban decentral water tanks      1.500000e-03
#           services rural water tanks                   1.540000e-03
#           services urban decentral water tanks         1.480000e-03
#           solid biomass                                2.043000e+08
#           urban central water tanks                    1.528200e-01
#
#                                                    Installed Capacity  \
# Generator Combined-Cycle Gas                             6.391000e+02
# ...

# %% [markdown]
# ### Substations

# %%
n.buses[n.buses.symbol=="substation"]

# %% [markdown]
# ### Transmission

# %%
n.plot(bus_sizes=0.01, link_widths=5)

# %% [markdown]
# ### Line Analysis

# %%
n.lines

# %% [markdown]
# Total line length

# %%
n.lines.length.sum()

# %% [markdown]
# Total link length

# %%
n.links.length.sum()
